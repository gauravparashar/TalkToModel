# %%
import pandas as pd

# %%
data = pd.read_csv('/home/gaurav_cse_21081/Session2023-24/ML-Class-Code/unit-3/iris.csv')

# %%
data.head(20)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width     variety
# 0            5.1          3.5           1.4          0.2      Setosa
# 1            4.9          3.0           1.4          0.2      Setosa
# 2            4.7          3.2           1.3          0.2      Setosa
# 3            5.0          3.3           1.4          0.2      Setosa
# 4            7.0          3.2           4.7          1.4  Versicolor
# 5            6.4          3.2           4.5          1.5  Versicolor
# 6            6.9          3.1           4.9          1.5  Versicolor
# 7            5.5          2.3           4.0          1.3  Versicolor
# 8            6.5          2.8           4.6          1.5  Versicolor
# 9            5.7          2.8           4.5          1.3  Versicolor
# 10           6.3          3.3           4.7          1.6  Versicolor
# 11           5.1          2.5           3.0          1.1  Versicolor
# 12           5.7          2.8           4.1          1.3  Versicolor
# ...
